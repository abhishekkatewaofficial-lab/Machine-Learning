# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
print("Data","Science","Mentorship","Program"
,"By","CampusX" ,sep= '-')
# Out:
# Data-Science-Mentorship-Program-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
celcius  = float(input("what is temperature in Celcius: "))

Fahrenheit =  (celcius * 1.8) + 32

print(f"the {celcius} degree celcius into Fahrenheit is {Fahrenheit} degree Fahrenheit ")
# Out:
# the 100.0 degree celcius into Fahrenheit is 212.0 degree Fahrenheit

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
num1 = int(input("choose 1st number"))
num2 = int(input("choose 2nd number"))

num1 , num2 = num2 , num1

print(f"num1 : {num1}  , num2: {num2}")
# Out:
# num1 : 2  , num2: 1

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
import math
x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))

x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))

distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

print(f"Distance between {x1,y1} and {x2,y2} is {distance}")
# Out:
# Distance between (1.0, 2.0) and (3.0, 4.0) is 2.8284271247461903

# %%
import math

p1 = (float(input("Enter x1: ")) , float(input("Enter y1: ")))
p2 = (float(input("Enter x2: ")) , float(input("Enter y2: ")))

distance = math.dist(p1,p2)

print(f"Distance between {p1} and {p2} is {math.dist(p1,p2)}")
# Out:
# Distance between (1.0, 2.0) and (3.0, 4.0) is 2.8284271247461903

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
principle = p = float(input("Write principle amount: "))
roi = r = float(input("Write Rate of Interest: "))
time = t = float(input("Write Time Period: "))

simple_interest = (p*r*t)/100
print(simple_interest)
# Out:
# 200.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
heads = int(input("Enter total heads: "))
legs = int(input("Enter total legs: "))


dogs = (legs - 2 * heads) // 2
chickens = heads - dogs


if legs % 2 != 0 or dogs < 0 or chickens < 0:
    print("Invalid input!")
else:
    print("Dogs =", dogs)
    print("Chickens =", chickens)
# Out:
# Dogs = 3
# Chickens = 9

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
n = int(input("for how many natural numbers you wanna find square? "))
# n = 10

for num in range(1,n+1):
    square = num*num
    print(f"square of {num} is : {square}")
# Out:
# square of 1 is : 1
# square of 2 is : 4
# square of 3 is : 9
# square of 4 is : 16
# square of 5 is : 25
# square of 6 is : 36
# square of 7 is : 49
# square of 8 is : 64
# square of 9 is : 81
# square of 10 is : 100

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
a1 = int(input("write first term"))
a2 = int(input("write second term"))
d = a2-a1
n =  int(input(" which term of series you wanna find: "))

nth_term  = a1 + (n-1)*d
print(f"{n}th term of series {a1},{a2}... is {nth_term}")
# Out:
# 5th term of series 10,20... is 50

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
n1 = float(input("numerator of fraction one: "))
d1 = float(input("denominator of fraction one: "))
n2 = float(input("numerator of fraction two: "))
d2 = float(input("denominator of fraction two: "))

f1 =n1/d1
f2 =n2/d2
print(f1)
print(f2)
# Out:
# 1.0
# 1.0

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
ht = int(input("enter height of milk tank "))
wt = int(input("enter width of milk tank "))
bt = int(input("enter breadth of milk tank "))

hg = int(input("enter height of milk glass "))
rg = int(input("enter radius of milk glass "))

volume_of_tank = ht*wt*bt
volume_of_glass = (22/7)*rg*rg*hg

print(f"we can fill {volume_of_tank//volume_of_glass} no of glasses ")
# Out:
# we can fill 318181.0 no of glasses
