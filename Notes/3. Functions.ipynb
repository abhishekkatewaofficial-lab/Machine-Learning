# %% [markdown]
# Pass is used jaha kuch nahi karna ho.
# 3rd line will execute the function.
#
# Advantage: Ek hi code block baar baar use kar sakte ha.

# %%
def hello_function():
    pass

hello_function()
hello_function()
hello_function()
hello_function()

# %%
def hello_function():
    print("Hello World")


hello_function()
hello_function()
hello_function()
hello_function()
# Out:
# Hello World
# Hello World
# Hello World
# Hello World

# %%
def hello_function():
    return "Hello World"


print(hello_function())
print(hello_function())
print(hello_function())
print(hello_function())
# Out:
# Hello World
# Hello World
# Hello World
# Hello World

# %% [markdown]
# *args collects all positional arguments into a tuple.
# **kwargs collects all keyword arguments into a dictionary.

# %%
def student_info(*loda , **lasun):
    print(loda)
    print(lasun)

student_info('Math', 'Art', name='John', age=22,)
# Out:
# ('Math', 'Art')
# {'name': 'John', 'age': 22}

# %%
def student_info(*args, **kwargs):
    print(args)
    print(kwargs)

courses = ['Math', 'Art']
info = {'name': 'John', 'age': 22}

student_info(courses, info)
# Out:
# (['Math', 'Art'], {'name': 'John', 'age': 22})
# {}

# %% [markdown]
# Now * and ** unpack the boxes before passing.

# %%
def student_info(*args, **kwargs):
    print(args)
    print(kwargs)

courses = ['Math', 'Art']
info = {'name': 'John', 'age': 22}

student_info(*courses, **info)
# Out:
# ('Math', 'Art')
# {'name': 'John', 'age': 22}
