# %% [markdown]
# = = cheks the equality.
# = assigns the value to variable
#
# X and Y ( both needs to be true to execute )
# X or Y ( only one needs to be true to execute )

# %% [markdown]
# Python ka id() function kisi object ki unique identity (identity number) return karta hai.

# %%
a = [1, 2, 3]
b = a

print(id(a))
print(id(b))
# Out:
# 4459240640
# 4459240640

# %%
a = [1, 2, 3]
b = [1, 2, 3]

print(id(a))
print(id(b))
# Out:
# 4459248256
# 4459248448

# %% [markdown]
# 0 and none are considered False  rest all True as Booleans

# %%
condition = 0

if condition:
    print("Hello World")

# %%
condition = 10

if condition:
    print("Hello World")
# Out:
# Hello World

# %%
condition = "Abhi"

if condition:
    print("Hello World")
# Out:
# Hello World
